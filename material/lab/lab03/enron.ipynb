# %% [markdown]
# ## [name] Type your name on the next line
# Caleb Chau

# %% [markdown]
# # SD212 Lab 03: Enron emails
#
# [webpage]: https://roche.work/sd212/lab/enron/
#
# ## Instructions
#
# Be sure to **actually read through the [lab webpage][webpage]**.
# There is a lot of useful information and detail not in this
# notebook file!
#
# Remember to put `%%bash` on the first line of a code cell to make
# Jupyter treat it as a bash script.
#
# Every question should be answered in the *same markdown cell* as
# the question header itself.
#
# You need to show your work. For most questions, that means adding
# a code cell (with `%%bash`) right below your answer to the question,
# where the output from that code cell shows the answer somehow.
#
# To test that you have everything working correctly, do
#
# 1.  Clear All Outputs
# 2.  Restart
# 3.  Run All
#
# And all of the computations and graphs should be re-generated.
#
# Good luck and have fun!

# %% [markdown]
# # Directory selection (determines 1% 10% or 100% dataset)
#
# The `%cd` command below is a special command to change the
# working directory in Jupyter. Initially we have it set to
# go to the 1% dataset folder. Change it to the 10% folder and
# then the 100% one when you are ready to "level up"!
#
# Note, this should determine the starting point for all future
# bash code blocks in this notebook.

# %%
# %bookmark notebook_dir
# %cd /home/mids/SD212/enron.01
# %bookmark enron_dir
# Out:
# [Errno 2] No such file or directory: '/home/mids/SD212/enron.01'
# /home/m281134/usna/sd212/material/lab/lab03

# %% [markdown]
# # Section 3: Initial questions

# %% [markdown]
# ## [Q1]
# > What sources of help (if any) did you utilize to complete this lab?
# > Please be specific.

# %% [markdown]
# ## [Q2]
# > What did you think of the lab overall? We hope that it was
# > challenging but instructive, and maybe even fun. Again, if you can
# > be specific that is helpful!

# %% [markdown]
# # Section 4: Single file

# %% [markdown]
# ## [Q3]
# > What is the name of Scott Neal's fraternity brother who plays the
# > accordion?
#
# > (Remember, for these problems, you need to do two things.  First,
# > make a new code cell below each question, starting with `%%bash`,
# > and put the commands there which you used to answer the question.
# > Second, you edit the markdown cell with the question itself, and add
# > your answer in text.)
#
# Mike Middleton

# %%
# %%bash
# %cd scott-s/
# grep -r 'accordion'
# Out:
# bash: line 1: fg: no job control
# enron.ipynb:    "> accordion?\n",
# enron.ipynb:    "grep -r 'accordion'"

# %% [markdown]
# ## [Q4]
# > Enron employee John Arnold sent an email discussing oil prices
# > saying (among other things), "Who cares if we nuke afghanistan?".
#
# > On what date was this email sent?
# > Type your date as `YYYY/MM/DD`.
#
# 2001/09/13

# %%
# %%bash
# %cd arnold-j/
# grep -r -B20 'nuke afghanistan?'
# Out:
# bash: line 1: fg: no job control
# enron.ipynb-     "ename": "",
# enron.ipynb-     "evalue": "",
# enron.ipynb-     "output_type": "error",
# enron.ipynb-     "traceback": [
# enron.ipynb-      "\u001bThe kernel failed to start as the Python Environment 'Python 3.14.3' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments."
# enron.ipynb-     ]
# enron.ipynb-    }
# enron.ipynb-   ],
# enron.ipynb-   "source": [
# enron.ipynb-    "%%bash\n",
# enron.ipynb-    "%cd scott-s/\n",
# enron.ipynb-    "grep -r 'accordion'"
# enron.ipynb-   ]
# enron.ipynb-  },
# enron.ipynb-  {
# enron.ipynb-   "cell_type": "markdown",
# enron.ipynb-   "metadata": {},
# enron.ipynb-   "source": [
# enron.ipynb-    "## [Q4]\n",
# enron.ipynb-    "> Enron employee John Arnold sent an email discussing oil prices\n",
# enron.ipynb:    "> saying (among other things), \"Who cares if we nuke afghanistan?\".\n",
# --
# enron.ipynb-    {
# enron.ipynb-     "name": "stdout",
# enron.ipynb-     "output_type": "stream",
# enron.ipynb-     "text": [
# enron.ipynb-      "arnold-j/sent_items/368.-Message-ID: <10052463.1075852720778.JavaMail.evans@thyme>\n",
# enron.ipynb-      "arnold-j/sent_items/368.-Date: Thu, 13 Sep 2001 09:08:32 -0700 (PDT)\n",
# enron.ipynb-      "arnold-j/sent_items/368.-From: john.arnold@enron.com\n",
# enron.ipynb-      "arnold-j/sent_items/368.-To: jennifer.fraser@enron.com\n",
# enron.ipynb-      "arnold-j/sent_items/368.-Subject: RE: crude buying\n",
# enron.ipynb-      "arnold-j/sent_items/368.-Mime-Version: 1.0\n",
# enron.ipynb-      "arnold-j/sent_items/368.-Content-Type: text/plain; charset=us-ascii\n",
# enron.ipynb-      "arnold-j/sent_items/368.-Content-Transfer-Encoding: 7bit\n",
# enron.ipynb-      "arnold-j/sent_items/368.-X-From: Arnold, John </O=ENRON/OU=NA/CN=RECIPIENTS/CN=JARNOLD>\n",
# enron.ipynb-      "arnold-j/sent_items/368.-X-To: Fraser, Jennifer </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Jfraser>\n",
# enron.ipynb-      "arnold-j/sent_items/368.-X-cc: \n",
# enron.ipynb-      "arnold-j/sent_items/368.-X-bcc: \n",
# enron.ipynb-      "arnold-j/sent_items/368.-X-Folder: \\JARNOLD (Non-Privileged)\\Arnold, John\\Sent Items\n",
# enron.ipynb-      "arnold-j/sent_items/368.-X-Origin: Arnold-J\n",
# enron.ipynb-      "arnold-j/sent_items/368.-X-FileName: JARNOLD (Non-Privileged).pst\n",
# enron.ipynb-      "arnold-j/sent_items/368.-\n",
# enron.ipynb:      "arnold-j/sent_items/368.:i've been selling.  was long 500 and selling out.  everybody will  be expecting the crude draws.  they dont matter.  think this is tremendously bearish all energy demand.  supply shocks are the only question, but I dont think US will end up fighting a war against the middle east.  Who cares if we nuke afghanistan?  \n"
# enron.ipynb-     ]
# enron.ipynb-    },
# enron.ipynb-    {
# enron.ipynb-     "ename": "",
# enron.ipynb-     "evalue": "",
# enron.ipynb-     "output_type": "error",
# enron.ipynb-     "traceback": [
# enron.ipynb-      "\u001bnotebook controller is DISPOSED. \n",
# enron.ipynb-      "\u001bView Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details."
# enron.ipynb-     ]
# enron.ipynb-    }
# enron.ipynb-   ],
# enron.ipynb-   "source": [
# enron.ipynb-    "%%bash\n",
# enron.ipynb-    "%cd arnold-j/\n",
# enron.ipynb:    "grep -r -B20 'nuke afghanistan?'"

# %% [markdown]
# ## [Q5]
# > On January 30 2002, Mark Germann from Sacramento sent an email to
# > a single Enron employee urging him to donate his ill-gotten gains.
#
# > What was the LAST NAME of the employee to whom Mr. Germann sent his
# > letter?
#
# Lay

# %%
# %%bash
# grep -r '30 Jan 2002' | grep -r 'Germann' | sort
# Out:
# enron.ipynb:      "lay-k/deleted_items/385.:Mark Germann\n"
# enron.ipynb:      "lay-k/deleted_items/385.:Mark Germann\n"
# enron.ipynb:      "lay-k/deleted_items/385.:Mark Germann\n",
# enron.ipynb:      "lay-k/deleted_items/385.:Mark Germann\n",
# enron.ipynb:    "> After receiving it, what did that employee do with Mr. Germann's\n",
# enron.ipynb:    "> On January 30 2002, Mark Germann from Sacramento sent an email to\n",
# enron.ipynb:    "> What was the LAST NAME of the employee to whom Mr. Germann sent his\n",
# enron.ipynb:    "grep -r '30 Jan 2002' | grep -r 'Germann' | sort"
# enron.ipynb:    "grep -r -A20 'Mark Germann'"

# %% [markdown]
# ## [Q6]
# > After receiving it, what did that employee do with Mr. Germann's
# > email?
#
# Delete it

# %%
# %%bash
# %cd lay-k/
# grep -r -A20 'Mark Germann'
# Out:
# bash: line 1: fg: no job control
# enron.ipynb:    "> On January 30 2002, Mark Germann from Sacramento sent an email to\n",
# enron.ipynb-    "> a single Enron employee urging him to donate his ill-gotten gains.\n",
# enron.ipynb-    "\n",
# enron.ipynb-    "> What was the LAST NAME of the employee to whom Mr. Germann sent his\n",
# enron.ipynb-    "> letter?\n",
# enron.ipynb-    "\n",
# enron.ipynb-    "Lay\n",
# enron.ipynb-    "\n"
# enron.ipynb-   ]
# enron.ipynb-  },
# enron.ipynb-  {
# enron.ipynb-   "cell_type": "code",
# enron.ipynb-   "execution_count": null,
# enron.ipynb-   "metadata": {},
# enron.ipynb-   "outputs": [
# enron.ipynb-    {
# enron.ipynb-     "name": "stdout",
# enron.ipynb-     "output_type": "stream",
# enron.ipynb-     "text": [
# enron.ipynb:      "lay-k/deleted_items/385.:Mark Germann\n",
# enron.ipynb:      "lay-k/deleted_items/385.:Mark Germann\n"
# enron.ipynb-     ]
# enron.ipynb-    },
# enron.ipynb-    {
# enron.ipynb-     "ename": "",
# enron.ipynb-     "evalue": "",
# enron.ipynb-     "output_type": "error",
# enron.ipynb-     "traceback": [
# enron.ipynb-      "\u001bnotebook controller is DISPOSED. \n",
# enron.ipynb-      "\u001bView Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details."
# enron.ipynb-     ]
# enron.ipynb-    }
# enron.ipynb-   ],
# enron.ipynb-   "source": [
# enron.ipynb-    "%%bash\n",
# enron.ipynb-    "grep -r '30 Jan 2002' | grep -r 'Germann' | sort"
# enron.ipynb-   ]
# enron.ipynb-  },
# enron.ipynb-  {
# enron.ipynb-   "cell_type": "markdown",
# enron.ipynb-   "metadata": {},
# --
# enron.ipynb:      "lay-k/deleted_items/385.:Mark Germann\n",
# enron.ipynb-      "lay-k/deleted_items/385.-1490 Sacramento St. 1C\n",
# enron.ipynb-      "lay-k/deleted_items/385.-San Francisco, CA 94109\n",
# enron.ipynb-      "lay-k/deleted_items/385.-msgermann@juno.com\n",
# enron.ipynb-      "lay-k/deleted_items/385.-\n",
# enron.ipynb-      "lay-k/deleted_items/385.-To Mr. Ken Lay,\n",
# enron.ipynb-      "lay-k/deleted_items/385.-\n",
# enron.ipynb-      "lay-k/deleted_items/385.-I'm writing to urge you to donate the millions of dollars you made from selling Enron stock before the company declared bankruptcy to funds, such as Enron Employee Transition Fund and REACH, that benefit the company's employees, who lost their retirement savings, and provide relief to low-income consumers in California, who can't afford to pay their energy bills.  Enron and you made millions out of the pocketbooks of California consumers and from the efforts of your employees.\n",
# enron.ipynb-      "lay-k/deleted_items/385.-\n",
# enron.ipynb-      "lay-k/deleted_items/385.-Indeed, while you netted well over a $100 million (you greedy son of a bitch), many of Enron's employees were financially devastated when the company declared bankruptcy and their retirement plans were wiped out.  And Enron made an astronomical profit during the California energy crisis last year.  As a result, there are thousands of consumers who are unable to pay their basic energy bills and the largest utility in the state is bankrupt.\n",
# enron.ipynb-      "lay-k/deleted_items/385.-\n",
# enron.ipynb-      "lay-k/deleted_items/385.-The New York Times reported that you sold $101 million worth of Enron stock while aggressively urging the company's employees to keep buying it.  Please donate this money to the funds set up to help repair the lives of those Americans hurt by Enron's underhanded dealings. Besides, your ass is going to jail anyway and you can't spend it there.\n",
# enron.ipynb-      "lay-k/deleted_items/385.-\n",
# enron.ipynb-      "lay-k/deleted_items/385.-Sincerely,\n",
# enron.ipynb-      "lay-k/deleted_items/385.-\n",
# enron.ipynb:      "lay-k/deleted_items/385.:Mark Germann\n"
# enron.ipynb-     ]
# enron.ipynb-    },
# enron.ipynb-    {
# enron.ipynb-     "ename": "",
# enron.ipynb-     "evalue": "",
# enron.ipynb-     "output_type": "error",
# enron.ipynb-     "traceback": [
# enron.ipynb-      "\u001bnotebook controller is DISPOSED. \n",
# enron.ipynb-      "\u001bView Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details."
# enron.ipynb-     ]
# enron.ipynb-    }
# enron.ipynb-   ],
# enron.ipynb-   "source": [
# enron.ipynb-    "%%bash\n",
# enron.ipynb-    "%cd lay-k/\n",
# enron.ipynb:    "grep -r -A20 'Mark Germann'"
# enron.ipynb-   ]
# enron.ipynb-  },
# enron.ipynb-  {
# enron.ipynb-   "cell_type": "markdown",
# enron.ipynb-   "metadata": {},
# enron.ipynb-   "source": [
# enron.ipynb-    "# Section 5: Make it count"
# enron.ipynb-   ]
# enron.ipynb-  },
# enron.ipynb-  {
# enron.ipynb-   "cell_type": "markdown",
# enron.ipynb-   "metadata": {},
# enron.ipynb-   "source": [
# enron.ipynb-    "## [Q7]\n",
# enron.ipynb-    "> What is the total number of emails in the dataset you are looking\n",
# enron.ipynb-    "> at?\n",
# enron.ipynb-    "\n",
# enron.ipynb-    "> Hint: don't count the folders. Look at the documentation for the\n",
# enron.ipynb-    "> `-type` flag to `find`.\n",
# enron.ipynb-    "\n",

# %% [markdown]
# # Section 5: Make it count

# %% [markdown]
# ## [Q7]
# > What is the total number of emails in the dataset you are looking
# > at?
#
# > Hint: don't count the folders. Look at the documentation for the
# > `-type` flag to `find`.
#
# 517402

# %%
# %%bash
# find . -name '*.' | wc -l
# Out:
# 1

# %% [markdown]
# ## [Q8]
# > How many emails were *sent* by Enron employees in the dataset during
# > the year 1999?
#
# > (For this question, only consider emails in subfolders named 'sent'
# > or 'sent_items')
#
# > Hint: remember to look at the *first* time the `Date` header appears
# > in the email. For that purpose, the `-m` option to grep might be
# > useful.
#
# > Hint 2: One oddball employee has his `sent` folder in a
# > sub-subfolder. Make sure you don't miss it!
#
# 64

# %%
# %%bash
# grep -r -m3 "1999" | grep "/sent" | wc -l
# grep -r -m3 "1999" | grep "/sent_items" | wc -l
# # grep -r -c "/sent" & "/sent_items" | wc -l
# Out:
# 2
# 1

# %% [markdown]
# ## [Q9]
# > How many emails mention golf in the subject line?
#
# > Hint: You will probably want to `grep` twice: First to extract the
# > first `Subject: ` header line, and secondly to do a
# > *case-insensitive* search for "golf" in each of those lines.
#
# > Check out the `-i` and `-c` flags to grep.
#
# 1048

# %%
# %%bash
# grep -r "Subject: " | grep -i "golf" | wc -l
# Out:
# 1

# %% [markdown]
# ## [Q10]
# > How many emails contain profanity?
#
# > There is some flexibility in your definition of "profanity" here,
# > but try to do your best to capture the kind of words that would be
# > "bleeped" on network TV or radio, without double-counting.
# > [This research paper][seven] contains a classic list of such
# > words.
#
# > Hint: make a regular expression for profanity for grep. Use the `|`
# > "alternation" operator to allow multiple possibilities.
#
# 119

# %%
# %%bash
# grep -r -i -E 'alcohol|beer|wine|whisky|whiskey|vodka' | wc -l
# Out:
# 1

# %% [markdown]
# # Section 6: Choose your own adventure

# %%
# this should change back to your lab directory
# %cd -b notebook_dir
# Out:
# (bookmark:notebook_dir) -> /home/m281134/usna/sd212/material/lab/lab03
# /home/m281134/usna/sd212/material/lab/lab03

# %% [markdown]
# ## [Q11]
# > What question are you trying to answer or investigate using this
# > data?
#
# How often the topic of fraud came up before and after ENRON filed for bankruptcy.

# %% [markdown]
# ## [Q12]
# > Create a bash cell (below this question) in your notebook that goes
# > through the email data and creates a file `mydata.csv` which has the
# > info needed to analyze your question.
#
# > Briefly explain the contents of your `mydata.csv` file. What does
# > each row and column represent?

# %%
# %%bash
# echo "fname;time" >'sampledata.csv'
# for fraudfile in $(find /home/mids/SD212/enron.1 -type f -exec grep -l -E 'fraud|scam|hoax|swindle|counterfeit|extortion' {} +)
# do
#     echo -n "$fraudfile;"
#     grep -m1 '^Date' "$fraudfile" | cut -d' ' -f6
# done >>'sampledata.csv'
# Out:
# find: ‘/home/mids/SD212/enron.1’: No such file or directory

# %% [markdown]
# ## [Q13]
# > Which dataset did you use to create your `mydata.csv` file?
#
# > a)  1% dataset (smallest)
# > b)  10% dataset
# > c)  100% dataset (largest)
#
# > (Write just the letter of your answer below.)
#
# b

# %% [markdown]
# ## [Q14]
# > Create a Python code cell that uses the data science libraries we
# > have seen such as Pandas and Plotly to read in your `mydata.csv`
# > file and create a graph from it. Save your graph as an image
# > `mygraph.png` (with 1000x600 dimensions) to turn in.

# %%
import pandas as pd
import plotly.express as px
fraud = pd.read_csv('sampledata.csv', sep=';')
fraud['hour'] = pd.to_datetime(fraud['time'], format='%H:%M:%S').dt.hour
px.histogram(fraud, x='hour', nbins=24, width=1000, height=600)

# %% [markdown]
# ## [Q15]
# > Having completed your analysis, what conclusions (if any) can you
# > draw about the original question? If you had time, what improvements
# > would you make or what would be the next thing you would
# > investigate?

# %% [markdown]
# # Example "Choose your own adventure": Eating time
#
# Please use this as an *example* of the kind of work we want
# to see from you for the last section.
#
# Here we are going to examine what times of day (hours) did
# people send an email that mentions "food".
#
# Keep in mind, you should look at something completely different
# for your own question! As in, if what you do is look at
# hours of the day when people mention "oil" for example, that
# is not going to earn a high grade.

# %%
# %%bash
# # First part: gathering data to sampledata.csv
# # We will make a csv that has the filename and date for every
# # email that mentions "food".
# # Note that we are using a semicolon to separate columns
# # because there are commas in the dates!
# echo "fname;time" >'sampledata.csv'
# for foodfile in $(find /home/mids/SD212/enron.01 -type f -exec grep -l 'food' {} +)
# do
#     echo -n "$foodfile;"
#     grep -m1 '^Date' "$foodfile" | cut -d' ' -f6
# done >>'sampledata.csv'
# Out:
# find: ‘/home/mids/SD212/enron.01’: No such file or directory

# %%
# Second part: processing the csv file using Python
import pandas as pd
import plotly.express as px
foodies = pd.read_csv('sampledata.csv', sep=';')
foodies['hour'] = pd.to_datetime(foodies['time'], format='%H:%M:%S').dt.hour
px.histogram(foodies, x='hour', nbins=24, width=1000, height=600)
